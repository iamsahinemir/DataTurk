# %%
import pandas as pd
import numpy as np

# %%
# Load the dataset into a pandas DataFrame
df = pd.read_csv('train.csv')

# Check the number of rows and columns in the dataset
print(f"Number of rows: {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")

# Check for missing or null values
print(df.isnull().sum())

# Look at the first few rows of the data
print(df.head())
# Out:
# Number of rows: 65289
# Number of columns: 122
# 69769                     0
# -946                      0
# 0.1613                37968
# 0.7959999999999999    43274
# Panl                  32923
#                       ...
# Mard                      1
# 0.0.14                  214
# 0.3333.2              32241
# 0.27                      1
# 0.28                      1
# Length: 122, dtype: int64
#     69769    -946  0.1613  0.7959999999999999  Panl  N  Bus2  0.0742  0  2  \
# 0  236977     -92     NaN                 NaN   NaN  Y  Othr     NaN  0  3
# 1  168821   -1646  0.1124              0.8504  Panl  N  Bus3  0.0387  0  2
# 2   94708   -1651  0.0263                 NaN  Blok  N  Bus3     NaN  0  2
# 3   84556    -977     NaN                 NaN   NaN  N  Rest     NaN  0  2
# 4  114510  365243  0.1067              0.8096  Panl  N  XNAA  0.0525  0  2
#
#    ...  1.0.1   -4670  0.9851.2  0.0.13 0.26  Mard 0.0.14  0.3333.2  0.27  \
# 0  ...    NaN -1994.0       NaN     NaN  0.0  Mard    0.0       NaN   0.0
# 1  ...    2.0 -2842.0    0.9891     0.0  0.0  Sind    0.0    0.3750   0.0
# 2  ...    4.0 -1345.0    0.9682     0.0  0.0  Sind    0.0    0.0417   0.0
# 3  ...    NaN  -852.0       NaN     NaN  0.0  Sind    0.0       NaN   0.0
# 4  ...    2.0 -4138.0    0.9861     0.0  0.0  Mard    0.0    0.4583   0.0
#
#    0.28
# 0   0.0
# 1   1.0
# 2   1.0
# 3   0.0
# 4   0.0
#
# [5 rows x 122 columns]

# %%
binary_label = df.iloc[:, -1]
print(binary_label)
# Out:
# 0        0.0
# 1        1.0
# 2        1.0
# 3        0.0
# 4        0.0
#         ...
# 11627    0.0
# 11628    0.0
# 11629    0.0
# 11630    1.0
# 11631    NaN
# Name: 0.28, Length: 11632, dtype: float64

# %%
print(binary_label.value_counts())
# Out:
# 0.0    10669
# 1.0      962
# Name: 0.28, dtype: int64

# %%
column_names = df.columns

print(column_names)
# Out:
# Index(['69769', '-946', '0.1613', '0.7959999999999999', 'Panl', 'N', 'Bus2',
#        '0.0742', '0', '2',
#        ...
#        '1.0.1', '-4670', '0.9851.2', '0.0.13', '0.26', 'Mard', '0.0.14',
#        '0.3333.2', '0.27', '0.28'],
#       dtype='object', length=122)

# %%
last_column_name = df.columns[-1]

print(last_column_name)
# Out:
# 0.28

# %%
import seaborn as sns
sns.countplot(x=binary_label)
# Out:
# <Axes: xlabel='0.28', ylabel='count'>

# %%
df['0.28'].isnull().sum()
# Out:
# 1

# %%
mode_value = df['0.28'].mode()[0]
mode_value
# Out:
# 0.0

# %%
# Fill the missing values with the mode value
df['0.28'].fillna(mode_value, inplace=True)

# %%
df['0.28'].isnull().sum()
# Out:
# 0

# %%
sns.countplot(x=binary_label)
# Out:
# <Axes: xlabel='0.28', ylabel='count'>
